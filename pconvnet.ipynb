# %% [markdown]
# # **Importing Libraries**

# %%
import numpy as np
import glob
from glob import glob
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torchvision
import torchvision.transforms as transforms 
import torch.nn as nn  
import torch.nn.functional as F
import torch.optim as optim
from torchvision import models
import copy
import cv2
from PIL import Image
import os
import shutil
from sklearn.model_selection import train_test_split
from torch.utils.data.dataloader import DataLoader

# %% [markdown]
# # **Data Proccessing**

# %%
def load_image(image_path, resize = True):  
  img = cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB)
  if resize:
    img = cv2.resize(img, (256, 256), interpolation = cv2.INTER_AREA)
  return img

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
def imshow(img, title):
  img = img.numpy().transpose(1,2,0)
  mean = np.array([0.4914, 0.4822, 0.4465])
  std = np.array([0.2470, 0.2435, 0.2616])
  img = std*img + mean
  img = np.clip(img, 0, 1)
  plt.figure(figsize=(8,4))
  plt.imshow(img)
  plt.axis('off')
  plt.title(title)
  plt.show()

# %%
def imshow_masked(img):
  npimg = img.numpy()
  plt.figure(figsize = (3, 3))
  plt.axis('off')
  plt.imshow(np.transpose(npimg, (1,2,0)))
  plt.show()

# %%
from torch.utils.data import Dataset, DataLoader
from PIL import Image, ImageChops 
train_path = '/kaggle/input/dl-dataset/Dataset/Training_Data/Masked_Train/'
ground_truth_path = '/kaggle/input/dl-dataset/Dataset/Training_Data/Unmasked_Train/'
train_mask_data = pd.read_csv(train_path + 'masked_info.csv').drop(['Unnamed: 0'],axis=1)
class ReconstructionDataset(Dataset):
  def __init__(self, flag_train, path, gt_path = "",image_dims = (256, 256), n_channels = 3):
    self.path = path
    self.flag_train = flag_train
    self.gt_path = gt_path
    self.mask_data = pd.read_csv(path + 'masked_info.csv').drop(['Unnamed: 0'],axis=1)
    self.image_dims = image_dims
    self.n_channels = n_channels
    self.resize = transforms.Resize(image_dims)
    self.to_tensor = transforms.ToTensor()
    
  def __len__(self):
    return len(self.mask_data)
    
  def __getitem__(self, index):
    if torch.is_tensor(index):
            index = index.tolist()
    #print(index)
    filename, y1, x1, y2, x2 = self.mask_data.loc[index,]
    image = Image.open(self.path + filename)
    X_input = self.resize(image)
    X_mask = self.Create_Mask(filename, self.mask_data)
    if(self.flag_train):
        ground_truth = Image.open(self.gt_path + filename)

        Y_output = self.resize(ground_truth)
        return self.to_tensor(X_input), self.to_tensor(X_mask), self.to_tensor(Y_output)
    
    return self.to_tensor(X_input), self.to_tensor(X_mask), filename, x1, y1, x2, y2

#   def Create_Mask(self, image):
#     mask = np.full((self.image_dims[0], self.image_dims[1], self.n_channels), 255, dtype = np.uint8)

#     for _ in range(np.random.randint(1, 10)):
#       x1, x2 = np.random.randint(1, self.image_dims[0]), np.random.randint(1, self.image_dims[0])
#       y1, y2 = np.random.randint(1, self.image_dims[1]), np.random.randint(1, self.image_dims[1])
#       thickness = np.random.randint(10,13)

#       cv2.line(mask, (x1, y1), (x2, y2), (1, 1, 1), thickness)
        
  def Create_Mask(self, filename, dataset):
    y1, x1, y2, x2 = dataset[dataset['filename'] == filename].iloc[0,1:]
    mask = Image.new(mode="RGB", size=(256, 256))
    for i in range(x1, x1+75): 
        for j in range(y1, y1+75):
            mask.putpixel((i,j),(255,255,255)) # for every pixel:
    for i in range(x2, x2+75): 
        for j in range(y2, y2+75):
            mask.putpixel((i,j),(255,255,255)) # for every pixel:
    inverted = ImageChops.invert(mask)
    return(inverted)

# %%
class ExtraDataset(Dataset):
    def __init__(self, path, image_dims = (256, 256), n_channels = 3):
        self.path = path
        self.image_dims = image_dims
        self.n_channels = n_channels
        self.resize = transforms.Resize(image_dims)
        self.to_tensor = transforms.ToTensor()
        self.dir_list = os.listdir(path)
    
    def __len__(self):
        return len(self.dir_list)

    def __getitem__(self, index):
        filename = self.dir_list[index]
        image = Image.open(self.path + filename)
        Y_output = self.resize(image)
        X_input, X_mask = self.Create_Mask(Y_output)
        return self.to_tensor(X_input), self.to_tensor(X_mask), self.to_tensor(Y_output)

    def Create_Mask(self, image):
        mask = np.full((self.image_dims[0], self.image_dims[1], self.n_channels), 255, dtype = np.uint8)

        for _ in range(2):
            x1, x2 = np.random.randint(1, self.image_dims[0]), np.random.randint(1, self.image_dims[0])
            y1, y2 = np.random.randint(1, self.image_dims[1]), np.random.randint(1, self.image_dims[1])
            thickness = np.random.randint(10,13)

            cv2.rectangle(mask, (x1, y1), (x2, y2), (1, 1, 1), -1)

        image = np.asarray(image)
        masked_image = cv2.bitwise_and(image, mask)
        return masked_image, mask

# %%
Trainset = ReconstructionDataset(1, '/kaggle/input/dl-dataset/Dataset/Training_Data/Masked_Train/', '/kaggle/input/dl-dataset/Dataset/Training_Data/Unmasked_Train/')
Testset = ReconstructionDataset(0, '/kaggle/input/dl-dataset/Dataset/Testing_Data/')

# %%
Trainloader = DataLoader(Trainset, batch_size = 4, shuffle = True)
Testloader = DataLoader(Testset, batch_size = 4, shuffle = False)

Train_dataiter = iter(Trainloader)
Test_dataiter = iter(Testloader)

# %%
X_in, X_mask, Y_out = next(Train_dataiter)
print(X_in.shape, X_mask.shape, Y_out.shape)
# Out:
# torch.Size([4, 3, 256, 256]) torch.Size([4, 3, 256, 256]) torch.Size([4, 3, 256, 256])

# %%
print('Masked Image')
imshow_masked(torchvision.utils.make_grid(X_in))
print('Masking Pattern')
imshow_masked(torchvision.utils.make_grid(X_mask))
print('Original Image')
imshow_masked(torchvision.utils.make_grid(Y_out))
# Out:
# Masked Image
# Masking Pattern
# Original Image

# %% [markdown]
# # **Training**

# %%
layers = 7

# %%
class PartialConvLayer(nn.Module):
  def __init__(self, in_channels, out_channels, bn = True, bias = False, sample = "none-3", activation = "relu"):
    super().__init__()
    self.bn = bn
    self.activation = activation

    if sample == "down-7":
      self.input_conv = nn.Conv2d(in_channels, out_channels, 7, 2, 3, bias = bias)
      self.mask_conv = nn.Conv2d(in_channels, out_channels, 7, 2, 3, bias = False)

    elif sample == "down-5":
      self.input_conv = nn.Conv2d(in_channels, out_channels, 5, 2, 2, bias = bias)
      self.mask_conv = nn.Conv2d(in_channels, out_channels, 5, 2, 2, bias = False)

    elif sample == "down-3":
      self.input_conv = nn.Conv2d(in_channels, out_channels, 3, 2, 1, bias = bias)
      self.mask_conv = nn.Conv2d(in_channels, out_channels, 3, 2, 1, bias = False)
    
    else:
      self.input_conv = nn.Conv2d(in_channels, out_channels, 3, 1, 1, bias=bias)
      self.mask_conv = nn.Conv2d(in_channels, out_channels, 3, 1, 1, bias=False)
      
    nn.init.constant_(self.mask_conv.weight, 1.0)
    nn.init.kaiming_normal_(self.input_conv.weight, a = 0, mode = "fan_in")

    for param in self.mask_conv.parameters():
      param.requires_grad = False

    if bn:
      self.batch_normalization = nn.BatchNorm2d(out_channels)

    if activation == "relu":
      self.activation = nn.ReLU()
    elif activation == "leaky_relu":
      self.activation == nn.LeakyReLU(negative_slope = 0.2)

  def forward(self, input_x, mask):
    output = self.input_conv(input_x * mask)
    with torch.no_grad():
      output_mask = self.mask_conv(mask)
    
    if self.input_conv.bias is not None:
      output_bias = self.input_conv.bias.view(1, -1, 1, 1).expand_as(output)
    else:
      output_bias = torch.zeros_like(output)

    mask_is_zero = (output_mask == 0)
    mask_sum = output_mask.masked_fill_(mask_is_zero, 1.0)

    output = (output - output_bias) / mask_sum + output_bias
    output = output.masked_fill(mask_is_zero, 0.0)

    new_mask = torch.ones_like(output)
    new_mask = new_mask.masked_fill_(mask_is_zero, 0.0)

    if self.bn:
      output = self.batch_normalization(output)
    #if hasattr(self, 'activation'):
      #output = self.activation(output)

    return output, new_mask

class PartialConvUNet(nn.Module):
  def __init__(self, input_size = 256, layer = 7):
    if 2**(layers + 1) != input_size:
      raise AssertionError

    super().__init__()
    self.freeze_enc_bn = False
    self.layers = layers

    self.encoder_1 = PartialConvLayer(3, 64, bn=False, sample="down-7")
    self.encoder_2 = PartialConvLayer(64, 128, sample="down-5")
    self.encoder_3 = PartialConvLayer(128, 256, sample="down-3")
    self.encoder_4 = PartialConvLayer(256, 512, sample="down-3")

    for i in range(5, layers + 1):
      name = "encoder_{:d}".format(i)
      setattr(self, name, PartialConvLayer(512, 512, sample="down-3"))
   
    for i in range(5, layers + 1):
      name = "decoder_{:d}".format(i)
      setattr(self, name, PartialConvLayer(512 + 512, 512, activation="leaky_relu"))
   
    self.decoder_4 = PartialConvLayer(512 + 256, 256, activation="leaky_relu")
    self.decoder_3 = PartialConvLayer(256 + 128, 128, activation="leaky_relu")
    self.decoder_2 = PartialConvLayer(128 + 64, 64, activation="leaky_relu")
    self.decoder_1 = PartialConvLayer(64 + 3, 3, bn=False, activation="", bias=True)

  def forward(self, input_x, mask):
    encoder_dict = {}
    mask_dict = {}
    key_prev = "h_0"
    encoder_dict[key_prev], mask_dict[key_prev] = input_x, mask

    for i in range(1, self.layers + 1):
      encoder_key = "encoder_{:d}".format(i)
      key = "h_{:d}".format(i)
      encoder_dict[key], mask_dict[key] = getattr(self, encoder_key)(encoder_dict[key_prev], mask_dict[key_prev])
      key_prev = key

    out_key = "h_{:d}".format(self.layers)
    out_data, out_mask = encoder_dict[out_key], mask_dict[out_key]

    for i in range(self.layers, 0, -1):
      encoder_key = "h_{:d}".format(i - 1)
      decoder_key = "decoder_{:d}".format(i)
      out_data = F.interpolate(out_data, scale_factor=2)
      out_mask = F.interpolate(out_mask, scale_factor=2)
      out_data = torch.cat([out_data, encoder_dict[encoder_key]], dim=1)
      out_mask = torch.cat([out_mask, mask_dict[encoder_key]], dim=1)
      out_data, out_mask = getattr(self, decoder_key)(out_data, out_mask)
    return out_data

  def train(self, mode=True):
    super().train(mode)
    if self.freeze_enc_bn:
      for name, module in self.named_modules():
        if isinstance(module, nn.BatchNorm2d) and "enc" in name:
          module.eval()

# %%
def Dice_coeff(dataloader):
  for (X_input, X_mask, Y_output) in dataloader:
    X_input, X_mask, Y_output = X_input.to(device), X_mask.to(device), Y_output.to(device)
    outputs = model(X_input, X_mask)
    eps = 1e-15
    outputs = outputs.view(-1)
    Y_output = Y_output.view(-1)
    intersection = (outputs * Y_output).sum()
    sum = (outputs.sum() + Y_output.sum())
  return (2*(intersection) / (sum + eps))

# %%
model = PartialConvUNet().to(device)
model = model.to(device)
#model.load_state_dict(torch.load('/kaggle/input/ckpt-pconvnet/1000000.pth'), strict=False)

# %%
loss_fn = nn.MSELoss()
opt = optim.Adam(model.parameters(), lr = 0.0005)
for param_group in opt.param_groups:
    print(param_group['lr'])
# Out:
# 0.0005

# %%
loss_epoch_arr = []
max_epochs = 30
batch_size = 4
min_loss = 1000

n_iters = np.ceil(7000/batch_size)
for epoch in range(max_epochs):
    print(f'Epoch Running: {epoch}')
    model.train()                               
    for i, (X_input, X_mask, Y_output) in enumerate(Trainloader, 0):

        X_input, X_mask, Y_output = X_input.to(device), X_mask.to(device), Y_output.to(device)

        opt.zero_grad()

        outputs = model(X_input, X_mask)
        loss = loss_fn(Y_output, outputs)
        loss.backward()
        opt.step()
        
        if min_loss > loss.item():
            min_loss = loss.item()
            best_model = copy.deepcopy(model.state_dict())
            print('Min loss %0.5f' % min_loss)
        
        if i % 100 == 0:
            print('Iteration: %d/%d, Loss: %0.005f' % (i, n_iters, loss.item()))
            
        del X_input, X_mask, Y_output
        torch.cuda.empty_cache()
        
    loss_epoch_arr.append(loss.item())
        
plt.plot(loss_epoch_arr)
plt.show()
# Out:
# Epoch Running: 0
# Min loss 0.38485
# Iteration: 0/1750, Loss: 0.38485
# Min loss 0.32545
# Min loss 0.23677
# Min loss 0.22602
# Min loss 0.20708
# Min loss 0.16256
# Min loss 0.07792
# Iteration: 100/1750, Loss: 0.16255
# Iteration: 200/1750, Loss: 0.12279
# Min loss 0.07511
# Min loss 0.05604
# Iteration: 300/1750, Loss: 0.07163
# Min loss 0.04724
# Min loss 0.02339
# Iteration: 400/1750, Loss: 0.10065
# Iteration: 500/1750, Loss: 0.03454
# Min loss 0.02211
# Min loss 0.01479
# Min loss 0.01228
# Iteration: 600/1750, Loss: 0.03173
# Min loss 0.01214
# Iteration: 700/1750, Loss: 0.01644
# Min loss 0.01130
# Min loss 0.00881
# Iteration: 800/1750, Loss: 0.02912
# Min loss 0.00832
# Iteration: 900/1750, Loss: 0.12825
# Iteration: 1000/1750, Loss: 0.01496
# Iteration: 1100/1750, Loss: 0.01907
# Min loss 0.00694
# Iteration: 1200/1750, Loss: 0.01397
# Iteration: 1300/1750, Loss: 0.01473
# Iteration: 1400/1750, Loss: 0.01422
# Min loss 0.00649
# Iteration: 1500/1750, Loss: 0.01547
# Iteration: 1600/1750, Loss: 0.03541
# Iteration: 1700/1750, Loss: 0.01983
# Epoch Running: 1
# Iteration: 0/1750, Loss: 0.01423
# Iteration: 100/1750, Loss: 0.05327
# Iteration: 200/1750, Loss: 0.02252
# Iteration: 300/1750, Loss: 0.01020
# Iteration: 400/1750, Loss: 0.01092
# Iteration: 500/1750, Loss: 0.01830
# Iteration: 600/1750, Loss: 0.01251
# Iteration: 700/1750, Loss: 0.01610
# Iteration: 800/1750, Loss: 0.01487
# Iteration: 900/1750, Loss: 0.01645
# Iteration: 1000/1750, Loss: 0.01895
# Iteration: 1100/1750, Loss: 0.01461
# Iteration: 1200/1750, Loss: 0.02151
# Iteration: 1300/1750, Loss: 0.01873
# Iteration: 1400/1750, Loss: 0.02520
# Iteration: 1500/1750, Loss: 0.00829
# Iteration: 1600/1750, Loss: 0.01439
# Min loss 0.00534
# Iteration: 1700/1750, Loss: 0.01567
# Epoch Running: 2
# Iteration: 0/1750, Loss: 0.01497
# Iteration: 100/1750, Loss: 0.01690
# Iteration: 200/1750, Loss: 0.01308
# Iteration: 300/1750, Loss: 0.01816
# Iteration: 400/1750, Loss: 0.03449
# Iteration: 500/1750, Loss: 0.01304
# Iteration: 600/1750, Loss: 0.02054
# Iteration: 700/1750, Loss: 0.02207
# Iteration: 800/1750, Loss: 0.01645
# Iteration: 900/1750, Loss: 0.03021
# Iteration: 1000/1750, Loss: 0.02291
# Iteration: 1100/1750, Loss: 0.02196
# Iteration: 1200/1750, Loss: 0.00777
# Min loss 0.00484
# Iteration: 1300/1750, Loss: 0.02022
# Iteration: 1400/1750, Loss: 0.01473
# Iteration: 1500/1750, Loss: 0.00932
# Iteration: 1600/1750, Loss: 0.01264
# Iteration: 1700/1750, Loss: 0.00751
# Epoch Running: 3
# Iteration: 0/1750, Loss: 0.01110
# Iteration: 100/1750, Loss: 0.02207
# Iteration: 200/1750, Loss: 0.01418
# Iteration: 300/1750, Loss: 0.01846
# Iteration: 400/1750, Loss: 0.01880
# Iteration: 500/1750, Loss: 0.01390
# Iteration: 600/1750, Loss: 0.03140
# Iteration: 700/1750, Loss: 0.01487
# Min loss 0.00470
# Iteration: 800/1750, Loss: 0.00707
# Min loss 0.00428
# Iteration: 900/1750, Loss: 0.00739
# Iteration: 1000/1750, Loss: 0.02534
# Iteration: 1100/1750, Loss: 0.00725
# Iteration: 1200/1750, Loss: 0.02261
# Iteration: 1300/1750, Loss: 0.00910
# Iteration: 1400/1750, Loss: 0.01110
# Iteration: 1500/1750, Loss: 0.01246
# Iteration: 1600/1750, Loss: 0.05071
# Iteration: 1700/1750, Loss: 0.01072
# Epoch Running: 4
# Iteration: 0/1750, Loss: 0.01443
# Iteration: 100/1750, Loss: 0.02607
# Iteration: 200/1750, Loss: 0.00789
# Iteration: 300/1750, Loss: 0.00715
# Min loss 0.00335
# Iteration: 400/1750, Loss: 0.01375
# Iteration: 500/1750, Loss: 0.00746
# Iteration: 600/1750, Loss: 0.01897
# Iteration: 700/1750, Loss: 0.00673
# Iteration: 800/1750, Loss: 0.00955
# Iteration: 900/1750, Loss: 0.00888
# Iteration: 1000/1750, Loss: 0.00911
# Iteration: 1100/1750, Loss: 0.00730
# Iteration: 1200/1750, Loss: 0.01359
# Iteration: 1300/1750, Loss: 0.00844
# Iteration: 1400/1750, Loss: 0.00801
# Iteration: 1500/1750, Loss: 0.01093
# Iteration: 1600/1750, Loss: 0.00887
# Iteration: 1700/1750, Loss: 0.02134
# Epoch Running: 5
# Iteration: 0/1750, Loss: 0.01128
# Iteration: 100/1750, Loss: 0.02056
# Iteration: 200/1750, Loss: 0.00843
# Iteration: 300/1750, Loss: 0.00909
# Iteration: 400/1750, Loss: 0.01112
# Iteration: 500/1750, Loss: 0.00892
# Iteration: 600/1750, Loss: 0.01868
# Iteration: 700/1750, Loss: 0.00906
# Iteration: 800/1750, Loss: 0.01504
# Iteration: 900/1750, Loss: 0.01274
# Iteration: 1000/1750, Loss: 0.00838
# Iteration: 1100/1750, Loss: 0.00842
# Iteration: 1200/1750, Loss: 0.00794
# Iteration: 1300/1750, Loss: 0.01436
# Iteration: 1400/1750, Loss: 0.00767
# Iteration: 1500/1750, Loss: 0.00612
# Iteration: 1600/1750, Loss: 0.00853
# Iteration: 1700/1750, Loss: 0.00790
# Epoch Running: 6
# Iteration: 0/1750, Loss: 0.01204
# Iteration: 100/1750, Loss: 0.02121
# Iteration: 200/1750, Loss: 0.01155
# Iteration: 300/1750, Loss: 0.04684
# Iteration: 400/1750, Loss: 0.01915
# Iteration: 500/1750, Loss: 0.02302
# Iteration: 600/1750, Loss: 0.00724
# Iteration: 700/1750, Loss: 0.00641
# Iteration: 800/1750, Loss: 0.02739
# Iteration: 900/1750, Loss: 0.01108
# Iteration: 1000/1750, Loss: 0.00790
# Iteration: 1100/1750, Loss: 0.01861
# Iteration: 1200/1750, Loss: 0.01009
# Iteration: 1300/1750, Loss: 0.00980
# Iteration: 1400/1750, Loss: 0.01043
# Iteration: 1500/1750, Loss: 0.00872
# Iteration: 1600/1750, Loss: 0.01116
# Iteration: 1700/1750, Loss: 0.00701
# Epoch Running: 7
# Iteration: 0/1750, Loss: 0.01427
# Iteration: 100/1750, Loss: 0.01643
# Iteration: 200/1750, Loss: 0.01366
# Iteration: 300/1750, Loss: 0.01477
# Iteration: 400/1750, Loss: 0.01093
# Iteration: 500/1750, Loss: 0.00692
# Iteration: 600/1750, Loss: 0.00777
# Iteration: 700/1750, Loss: 0.01213
# Iteration: 800/1750, Loss: 0.01419
# Iteration: 900/1750, Loss: 0.01665
# Iteration: 1000/1750, Loss: 0.00785
# Iteration: 1100/1750, Loss: 0.01060
# Iteration: 1200/1750, Loss: 0.00815
# Iteration: 1300/1750, Loss: 0.01505
# Iteration: 1400/1750, Loss: 0.00744
# Iteration: 1500/1750, Loss: 0.00748
# Iteration: 1600/1750, Loss: 0.00966
# Iteration: 1700/1750, Loss: 0.02097
# Epoch Running: 8
# Iteration: 0/1750, Loss: 0.00956
# Iteration: 100/1750, Loss: 0.00804
# Iteration: 200/1750, Loss: 0.00484
# Iteration: 300/1750, Loss: 0.00941
# Iteration: 400/1750, Loss: 0.02965
# Iteration: 500/1750, Loss: 0.00700
# Iteration: 600/1750, Loss: 0.01111
# Min loss 0.00302
# Iteration: 700/1750, Loss: 0.01143
# Iteration: 800/1750, Loss: 0.00835
# Iteration: 900/1750, Loss: 0.01178
# Iteration: 1000/1750, Loss: 0.01402
# Iteration: 1100/1750, Loss: 0.00567
# Iteration: 1200/1750, Loss: 0.01530
# Iteration: 1300/1750, Loss: 0.01525
# Iteration: 1400/1750, Loss: 0.00808
# Iteration: 1500/1750, Loss: 0.01315
# Iteration: 1600/1750, Loss: 0.01701
# Min loss 0.00300
# Iteration: 1700/1750, Loss: 0.00987
# Epoch Running: 9
# Iteration: 0/1750, Loss: 0.01243
# Iteration: 100/1750, Loss: 0.01463
# Iteration: 200/1750, Loss: 0.02030
# Iteration: 300/1750, Loss: 0.00742
# Iteration: 400/1750, Loss: 0.00728
# Iteration: 500/1750, Loss: 0.00905
# Iteration: 600/1750, Loss: 0.04157
# Iteration: 700/1750, Loss: 0.01077
# Iteration: 800/1750, Loss: 0.05962
# Iteration: 900/1750, Loss: 0.01597
# Iteration: 1000/1750, Loss: 0.01681
# Iteration: 1100/1750, Loss: 0.01266
# Iteration: 1200/1750, Loss: 0.01864
# Iteration: 1300/1750, Loss: 0.00629
# Iteration: 1400/1750, Loss: 0.03267
# Iteration: 1500/1750, Loss: 0.00492
# Iteration: 1600/1750, Loss: 0.03784
# Iteration: 1700/1750, Loss: 0.01613
# Epoch Running: 10
# Iteration: 0/1750, Loss: 0.01048
# Iteration: 100/1750, Loss: 0.01922
# Iteration: 200/1750, Loss: 0.02362
# Iteration: 300/1750, Loss: 0.03626
# Iteration: 400/1750, Loss: 0.02060
# Min loss 0.00279
# Iteration: 500/1750, Loss: 0.00548
# Iteration: 600/1750, Loss: 0.00887
# Iteration: 700/1750, Loss: 0.00459
# Iteration: 800/1750, Loss: 0.00855
# Iteration: 900/1750, Loss: 0.02343
# Iteration: 1000/1750, Loss: 0.03210
# Iteration: 1100/1750, Loss: 0.02376
# Iteration: 1200/1750, Loss: 0.00757
# Iteration: 1300/1750, Loss: 0.00782
# Iteration: 1400/1750, Loss: 0.01116
# Iteration: 1500/1750, Loss: 0.00507
# Iteration: 1600/1750, Loss: 0.03398
# Min loss 0.00252
# Iteration: 1700/1750, Loss: 0.00994
# Epoch Running: 11
# Iteration: 0/1750, Loss: 0.00754
# Iteration: 100/1750, Loss: 0.00751
# Iteration: 200/1750, Loss: 0.00547
# Iteration: 300/1750, Loss: 0.00809
# Iteration: 400/1750, Loss: 0.01306
# Iteration: 500/1750, Loss: 0.00996
# Iteration: 600/1750, Loss: 0.02378
# Iteration: 700/1750, Loss: 0.01153
# Iteration: 800/1750, Loss: 0.00633
# Iteration: 900/1750, Loss: 0.01004
# Iteration: 1000/1750, Loss: 0.00912
# Iteration: 1100/1750, Loss: 0.03311
# Iteration: 1200/1750, Loss: 0.00868
# Iteration: 1300/1750, Loss: 0.00544
# Iteration: 1400/1750, Loss: 0.00724
# Iteration: 1500/1750, Loss: 0.00598
# Iteration: 1600/1750, Loss: 0.00818
# Iteration: 1700/1750, Loss: 0.01126
# Epoch Running: 12
# Iteration: 0/1750, Loss: 0.00678
# Iteration: 100/1750, Loss: 0.00912
# Iteration: 200/1750, Loss: 0.03267
# Iteration: 300/1750, Loss: 0.00932
# Iteration: 400/1750, Loss: 0.00528
# Iteration: 500/1750, Loss: 0.00712
# Iteration: 600/1750, Loss: 0.01633
# Iteration: 700/1750, Loss: 0.01228
# Iteration: 800/1750, Loss: 0.00853
# Iteration: 900/1750, Loss: 0.00596
# Iteration: 1000/1750, Loss: 0.00829
# Iteration: 1100/1750, Loss: 0.01121
# Iteration: 1200/1750, Loss: 0.00651
# Iteration: 1300/1750, Loss: 0.01161
# Iteration: 1400/1750, Loss: 0.00657
# Iteration: 1500/1750, Loss: 0.00965
# Iteration: 1600/1750, Loss: 0.01205
# Iteration: 1700/1750, Loss: 0.01212
# Epoch Running: 13
# Iteration: 0/1750, Loss: 0.00803
# Iteration: 100/1750, Loss: 0.02067
# Iteration: 200/1750, Loss: 0.01393
# Iteration: 300/1750, Loss: 0.01078
# Iteration: 400/1750, Loss: 0.01089
# Iteration: 500/1750, Loss: 0.00845
# Iteration: 600/1750, Loss: 0.00296
# Iteration: 700/1750, Loss: 0.00543
# Iteration: 800/1750, Loss: 0.01550
# Iteration: 900/1750, Loss: 0.03870
# Iteration: 1000/1750, Loss: 0.00733
# Iteration: 1100/1750, Loss: 0.04581
# Iteration: 1200/1750, Loss: 0.03829
# Iteration: 1300/1750, Loss: 0.01093
# Iteration: 1400/1750, Loss: 0.00461
# Iteration: 1500/1750, Loss: 0.00609
# Iteration: 1600/1750, Loss: 0.01003
# Min loss 0.00240
# Iteration: 1700/1750, Loss: 0.00240
# Epoch Running: 14
# Iteration: 0/1750, Loss: 0.00682
# Iteration: 100/1750, Loss: 0.00871
# Iteration: 200/1750, Loss: 0.01819
# Iteration: 300/1750, Loss: 0.00431
# Iteration: 400/1750, Loss: 0.00632
# Iteration: 500/1750, Loss: 0.01092
# Iteration: 600/1750, Loss: 0.00553
# Iteration: 700/1750, Loss: 0.00668
# Iteration: 800/1750, Loss: 0.00503
# Iteration: 900/1750, Loss: 0.01916
# Iteration: 1000/1750, Loss: 0.00889
# Iteration: 1100/1750, Loss: 0.00685
# Iteration: 1200/1750, Loss: 0.00541
# Iteration: 1300/1750, Loss: 0.01307
# Iteration: 1400/1750, Loss: 0.00283
# Iteration: 1500/1750, Loss: 0.00737
# Iteration: 1600/1750, Loss: 0.01430
# Iteration: 1700/1750, Loss: 0.01915
# Epoch Running: 15
# Iteration: 0/1750, Loss: 0.01121
# Iteration: 100/1750, Loss: 0.02007
# Iteration: 200/1750, Loss: 0.01643
# Iteration: 300/1750, Loss: 0.00471
# Iteration: 400/1750, Loss: 0.00526
# Iteration: 500/1750, Loss: 0.01008
# Iteration: 600/1750, Loss: 0.01753
# Iteration: 700/1750, Loss: 0.00555
# Iteration: 800/1750, Loss: 0.00344
# Iteration: 900/1750, Loss: 0.00530
# Iteration: 1000/1750, Loss: 0.00458
# Iteration: 1100/1750, Loss: 0.01195
# Iteration: 1200/1750, Loss: 0.01574
# Iteration: 1300/1750, Loss: 0.02252
# Iteration: 1400/1750, Loss: 0.00565
# Iteration: 1500/1750, Loss: 0.00629
# Iteration: 1600/1750, Loss: 0.00702
# Iteration: 1700/1750, Loss: 0.00371
# Epoch Running: 16
# Iteration: 0/1750, Loss: 0.01656
# Iteration: 100/1750, Loss: 0.00942
# Iteration: 200/1750, Loss: 0.01447
# Iteration: 300/1750, Loss: 0.01148
# Iteration: 400/1750, Loss: 0.03207
# Iteration: 500/1750, Loss: 0.00581
# Iteration: 600/1750, Loss: 0.01321
# Iteration: 700/1750, Loss: 0.00608
# Iteration: 800/1750, Loss: 0.01394
# Iteration: 900/1750, Loss: 0.00520
# Iteration: 1000/1750, Loss: 0.03351
# Iteration: 1100/1750, Loss: 0.00897
# Iteration: 1200/1750, Loss: 0.00843
# Iteration: 1300/1750, Loss: 0.00902
# Iteration: 1400/1750, Loss: 0.00748
# Iteration: 1500/1750, Loss: 0.00679
# Iteration: 1600/1750, Loss: 0.00788
# Iteration: 1700/1750, Loss: 0.00709
# Epoch Running: 17
# Iteration: 0/1750, Loss: 0.01224
# Iteration: 100/1750, Loss: 0.01806
# Iteration: 200/1750, Loss: 0.00537
# Iteration: 300/1750, Loss: 0.00940
# Iteration: 400/1750, Loss: 0.00894
# Iteration: 500/1750, Loss: 0.01553
# Iteration: 600/1750, Loss: 0.00669
# Iteration: 700/1750, Loss: 0.00399
# Iteration: 800/1750, Loss: 0.00604
# Iteration: 900/1750, Loss: 0.00887
# Iteration: 1000/1750, Loss: 0.02656
# Iteration: 1100/1750, Loss: 0.00496
# Iteration: 1200/1750, Loss: 0.01823
# Iteration: 1300/1750, Loss: 0.00912
# Iteration: 1400/1750, Loss: 0.01721
# Iteration: 1500/1750, Loss: 0.04263
# Iteration: 1600/1750, Loss: 0.01785
# Iteration: 1700/1750, Loss: 0.01684
# Epoch Running: 18
# Iteration: 0/1750, Loss: 0.01219
# Iteration: 100/1750, Loss: 0.00397
# Iteration: 200/1750, Loss: 0.03075
# Iteration: 300/1750, Loss: 0.00673
# Iteration: 400/1750, Loss: 0.00513
# Iteration: 500/1750, Loss: 0.00889
# Iteration: 600/1750, Loss: 0.00496
# Iteration: 700/1750, Loss: 0.01259
# Iteration: 800/1750, Loss: 0.00727
# Iteration: 900/1750, Loss: 0.00616
# Iteration: 1000/1750, Loss: 0.00762
# Iteration: 1100/1750, Loss: 0.00518
# Iteration: 1200/1750, Loss: 0.02043
# Iteration: 1300/1750, Loss: 0.00714
# Iteration: 1400/1750, Loss: 0.01054
# Iteration: 1500/1750, Loss: 0.01023
# Iteration: 1600/1750, Loss: 0.00451
# Iteration: 1700/1750, Loss: 0.00490
# Epoch Running: 19
# Iteration: 0/1750, Loss: 0.00647
# Iteration: 100/1750, Loss: 0.00506
# Iteration: 200/1750, Loss: 0.01036
# Iteration: 300/1750, Loss: 0.00726
# Iteration: 400/1750, Loss: 0.01456
# Iteration: 500/1750, Loss: 0.01080
# Iteration: 600/1750, Loss: 0.01580
# Iteration: 700/1750, Loss: 0.00736
# Iteration: 800/1750, Loss: 0.00788
# Iteration: 900/1750, Loss: 0.00965
# Iteration: 1000/1750, Loss: 0.01115
# Iteration: 1100/1750, Loss: 0.00748
# Iteration: 1200/1750, Loss: 0.01317
# Iteration: 1300/1750, Loss: 0.00504
# Iteration: 1400/1750, Loss: 0.00879
# Iteration: 1500/1750, Loss: 0.01285
# Iteration: 1600/1750, Loss: 0.00902
# Iteration: 1700/1750, Loss: 0.00656
# Epoch Running: 20
# Iteration: 0/1750, Loss: 0.01289
# Iteration: 100/1750, Loss: 0.00911
# Iteration: 200/1750, Loss: 0.00714
# Iteration: 300/1750, Loss: 0.00814
# Iteration: 400/1750, Loss: 0.01152
# Min loss 0.00228
# Iteration: 500/1750, Loss: 0.00415
# Iteration: 600/1750, Loss: 0.02042
# Iteration: 700/1750, Loss: 0.00511
# Iteration: 800/1750, Loss: 0.01589
# Iteration: 900/1750, Loss: 0.00742
# Iteration: 1000/1750, Loss: 0.00772
# Iteration: 1100/1750, Loss: 0.00537
# Iteration: 1200/1750, Loss: 0.01564
# Iteration: 1300/1750, Loss: 0.01657
# Iteration: 1400/1750, Loss: 0.00482
# Iteration: 1500/1750, Loss: 0.00643
# Iteration: 1600/1750, Loss: 0.01025
# Iteration: 1700/1750, Loss: 0.00634
# Epoch Running: 21
# Iteration: 0/1750, Loss: 0.00648
# Iteration: 100/1750, Loss: 0.00602
# Iteration: 200/1750, Loss: 0.00754
# Iteration: 300/1750, Loss: 0.00522
# Iteration: 400/1750, Loss: 0.01354
# Iteration: 500/1750, Loss: 0.00685
# Iteration: 600/1750, Loss: 0.00469
# Iteration: 700/1750, Loss: 0.01964
# Iteration: 800/1750, Loss: 0.00804
# Iteration: 900/1750, Loss: 0.00947
# Iteration: 1000/1750, Loss: 0.00570
# Iteration: 1100/1750, Loss: 0.00956
# Iteration: 1200/1750, Loss: 0.01149
# Iteration: 1300/1750, Loss: 0.01261
# Iteration: 1400/1750, Loss: 0.00538
# Iteration: 1500/1750, Loss: 0.00547
# Iteration: 1600/1750, Loss: 0.00624
# Iteration: 1700/1750, Loss: 0.00561
# Epoch Running: 22
# Iteration: 0/1750, Loss: 0.01204
# Iteration: 100/1750, Loss: 0.00439
# Iteration: 200/1750, Loss: 0.00454
# Iteration: 300/1750, Loss: 0.00913
# Iteration: 400/1750, Loss: 0.00972
# Iteration: 500/1750, Loss: 0.00437
# Iteration: 600/1750, Loss: 0.00737
# Iteration: 700/1750, Loss: 0.01134
# Iteration: 800/1750, Loss: 0.01114
# Iteration: 900/1750, Loss: 0.00695
# Iteration: 1000/1750, Loss: 0.00670
# Iteration: 1100/1750, Loss: 0.00491
# Iteration: 1200/1750, Loss: 0.00707
# Iteration: 1300/1750, Loss: 0.00539
# Iteration: 1400/1750, Loss: 0.00542
# Iteration: 1500/1750, Loss: 0.00537
# Iteration: 1600/1750, Loss: 0.00921
# Iteration: 1700/1750, Loss: 0.00652
# Epoch Running: 23
# Iteration: 0/1750, Loss: 0.00564
# Iteration: 100/1750, Loss: 0.01066
# Iteration: 200/1750, Loss: 0.01243
# Iteration: 300/1750, Loss: 0.00599
# Iteration: 400/1750, Loss: 0.02341
# Iteration: 500/1750, Loss: 0.04566
# Iteration: 600/1750, Loss: 0.00613
# Iteration: 700/1750, Loss: 0.00773
# Iteration: 800/1750, Loss: 0.00703
# Iteration: 900/1750, Loss: 0.01091
# Iteration: 1000/1750, Loss: 0.00680
# Iteration: 1100/1750, Loss: 0.00666
# Iteration: 1200/1750, Loss: 0.00784
# Iteration: 1300/1750, Loss: 0.01148
# Iteration: 1400/1750, Loss: 0.01927
# Iteration: 1500/1750, Loss: 0.00866
# Iteration: 1600/1750, Loss: 0.01146
# Iteration: 1700/1750, Loss: 0.03322
# Epoch Running: 24
# Iteration: 0/1750, Loss: 0.00610
# Iteration: 100/1750, Loss: 0.00428
# Iteration: 200/1750, Loss: 0.00816
# Iteration: 300/1750, Loss: 0.00574
# Iteration: 400/1750, Loss: 0.01126
# Iteration: 500/1750, Loss: 0.00678
# Iteration: 600/1750, Loss: 0.00516
# Iteration: 700/1750, Loss: 0.00575
# Iteration: 800/1750, Loss: 0.00388
# Iteration: 900/1750, Loss: 0.00959
# Iteration: 1000/1750, Loss: 0.00730
# Iteration: 1100/1750, Loss: 0.00416
# Iteration: 1200/1750, Loss: 0.00605
# Iteration: 1300/1750, Loss: 0.00644
# Iteration: 1400/1750, Loss: 0.00620
# Iteration: 1500/1750, Loss: 0.02731
# Iteration: 1600/1750, Loss: 0.00947
# Iteration: 1700/1750, Loss: 0.01175
# Epoch Running: 25
# Iteration: 0/1750, Loss: 0.00400
# Iteration: 100/1750, Loss: 0.00994
# Iteration: 200/1750, Loss: 0.01216
# Iteration: 300/1750, Loss: 0.00537
# Iteration: 400/1750, Loss: 0.00636
# Iteration: 500/1750, Loss: 0.01228
# Iteration: 600/1750, Loss: 0.01196
# Iteration: 700/1750, Loss: 0.00874
# Min loss 0.00226
# Iteration: 800/1750, Loss: 0.00679
# Iteration: 900/1750, Loss: 0.00430
# Iteration: 1000/1750, Loss: 0.01065
# Iteration: 1100/1750, Loss: 0.00640
# Iteration: 1200/1750, Loss: 0.01227
# Iteration: 1300/1750, Loss: 0.01841
# Iteration: 1400/1750, Loss: 0.01102
# Iteration: 1500/1750, Loss: 0.01120
# Iteration: 1600/1750, Loss: 0.00536
# Iteration: 1700/1750, Loss: 0.00423
# Epoch Running: 26
# Iteration: 0/1750, Loss: 0.01227
# Iteration: 100/1750, Loss: 0.00988
# Iteration: 200/1750, Loss: 0.00477
# Iteration: 300/1750, Loss: 0.00632
# Iteration: 400/1750, Loss: 0.00719
# Iteration: 500/1750, Loss: 0.00482
# Iteration: 600/1750, Loss: 0.00718
# Iteration: 700/1750, Loss: 0.00404
# Iteration: 800/1750, Loss: 0.01621
# Iteration: 900/1750, Loss: 0.00620
# Iteration: 1000/1750, Loss: 0.00564
# Iteration: 1100/1750, Loss: 0.00533
# Iteration: 1200/1750, Loss: 0.00402
# Iteration: 1300/1750, Loss: 0.00830
# Iteration: 1400/1750, Loss: 0.00746
# Iteration: 1500/1750, Loss: 0.01057
# Iteration: 1600/1750, Loss: 0.00535
# Iteration: 1700/1750, Loss: 0.00571
# Epoch Running: 27
# Iteration: 0/1750, Loss: 0.01863
# Iteration: 100/1750, Loss: 0.00592
# Iteration: 200/1750, Loss: 0.00699
# Iteration: 300/1750, Loss: 0.00593
# Iteration: 400/1750, Loss: 0.00579
# Iteration: 500/1750, Loss: 0.01028
# Iteration: 600/1750, Loss: 0.00658
# Iteration: 700/1750, Loss: 0.00444
# Iteration: 800/1750, Loss: 0.00510
# Iteration: 900/1750, Loss: 0.00641
# Iteration: 1000/1750, Loss: 0.00714
# Iteration: 1100/1750, Loss: 0.00457
# Iteration: 1200/1750, Loss: 0.00624
# Iteration: 1300/1750, Loss: 0.00550
# Iteration: 1400/1750, Loss: 0.00837
# Iteration: 1500/1750, Loss: 0.00673
# Iteration: 1600/1750, Loss: 0.01015
# Iteration: 1700/1750, Loss: 0.00541
# Epoch Running: 28
# Iteration: 0/1750, Loss: 0.00563
# Iteration: 100/1750, Loss: 0.03870
# Iteration: 200/1750, Loss: 0.00375
# Iteration: 300/1750, Loss: 0.01191
# Iteration: 400/1750, Loss: 0.00627
# Iteration: 500/1750, Loss: 0.00605
# Iteration: 600/1750, Loss: 0.00631
# Iteration: 700/1750, Loss: 0.04558
# Iteration: 800/1750, Loss: 0.02323
# Iteration: 900/1750, Loss: 0.01037
# Iteration: 1000/1750, Loss: 0.01054
# Iteration: 1100/1750, Loss: 0.00839
# Iteration: 1200/1750, Loss: 0.01138
# Iteration: 1300/1750, Loss: 0.00428
# Iteration: 1400/1750, Loss: 0.01093
# Iteration: 1500/1750, Loss: 0.00388
# Iteration: 1600/1750, Loss: 0.00454
# Iteration: 1700/1750, Loss: 0.00448
# Epoch Running: 29
# Iteration: 0/1750, Loss: 0.00438
# Iteration: 100/1750, Loss: 0.01309
# Iteration: 200/1750, Loss: 0.00710
# Iteration: 300/1750, Loss: 0.00790
# Iteration: 400/1750, Loss: 0.00921
# Iteration: 500/1750, Loss: 0.01268
# Iteration: 600/1750, Loss: 0.00676
# Iteration: 700/1750, Loss: 0.01005
# Iteration: 800/1750, Loss: 0.01047
# Iteration: 900/1750, Loss: 0.00289
# Iteration: 1000/1750, Loss: 0.00641
# Iteration: 1100/1750, Loss: 0.00998
# Iteration: 1200/1750, Loss: 0.00672
# Iteration: 1300/1750, Loss: 0.01940
# Iteration: 1400/1750, Loss: 0.01065
# Iteration: 1500/1750, Loss: 0.00529
# Iteration: 1600/1750, Loss: 0.00421
# Iteration: 1700/1750, Loss: 0.00611

# %%
model.load_state_dict(best_model)
torch.save(model,'/kaggle/working/pconv_30_0.0005.pth')

# %% [markdown]
# # **Testing**

# %%
import cv2 as cv
trans = transforms.ToPILImage()
def Create_Mask(filename, dataset):
    y1, x1, y2, x2 = dataset[dataset['filename'] == filename].iloc[0,1:]
    mask = Image.new(mode="RGB", size=(256, 256))
    for i in range(x1, x1+75): 
        for j in range(y1, y1+75):
            mask.putpixel((i,j),(255,255,255)) # for every pixel:
    for i in range(x2, x2+75): 
        for j in range(y2, y2+75):
            mask.putpixel((i,j),(255,255,255)) # for every pixel:
    inverted = ImageChops.invert(mask)
    return(inverted)

    image = np.asarray(image)
    masked_image = cv2.bitwise_and(image, mask)
    return masked_image, mask

test_path = '/kaggle/input/dl-dataset/Dataset/Testing_Data/'
to_tensor = transforms.ToTensor()
#transform = T.ToPILImage()
import numpy as np
#from google.colab.patches import cv2_imshow
def submission_data(test_path):
    test_mask_data = pd.read_csv(test_path + 'masked_info.csv').drop(['Unnamed: 0'],axis=1)
    submission = []
    for i, (sample_inputs, sample_masks, filename, x1, y1, x2, y2) in enumerate(Testloader, 0):
        if (i%25 == 0):
            print("Nigga 25 iterations ho gyi:" , i)
        
        #sample_inputs, sample_masks, filename, x1, y1, x2, y2= next(Test_dataiter)
        sample_inputs, sample_masks = sample_inputs.cuda(), sample_masks.cuda()
        #model.load_state_dict(torch.load('/kaggle/input/ckpt-pconvnet/1000000.pth'), strict=False)
        model.eval()
        with torch.no_grad():
            preds = model(sample_inputs, sample_masks)
#         import matplotlib.pyplot as plt
#         plt.imshow(preds)
#         print(preds.size())
        for batch in range(4):
            
            pred = trans(preds[batch])
#             import matplotlib.pyplot as plt
#             plt.imshow(pred)
            im = np.array(pred)
            #print(im)
            b, g, r = cv.split(im)
            result = np.zeros((256,256))
            normalized_b = cv.normalize(b,result, 0, 1, cv.NORM_MINMAX, dtype=cv.CV_32F)
            normalized_g = cv.normalize(g,result, 0, 1, cv.NORM_MINMAX, dtype=cv.CV_32F)
            normalized_r = cv.normalize(r,result, 0, 1, cv.NORM_MINMAX, dtype=cv.CV_32F)
#             for i in range(256):
#                 for j in range(256):
#                     temp1 = filename[batch] + '_' + 'box1' + '_' +  str(i) + '_' + str(j) + '_'
#                     submission.append((temp1 + '0', normalized_b[i,j]))
#                     submission.append((temp1 + '1', normalized_g[i,j]))
#                     submission.append((temp1 + '2', normalized_r[i,j]))
                    
            #print(filename[batch])
            for i in range(y1[batch].item() , y1[batch].item()+75):
                for j in range(x1[batch].item(), x1[batch].item()+75):
                    temp1 = filename[batch] + '_' + 'box1' + '_' +  str(i) + '_' + str(j) + '_'
                    submission.append((temp1 + '0', normalized_b[i,j]))
                    submission.append((temp1 + '1', normalized_g[i,j]))
                    submission.append((temp1 + '2', normalized_r[i,j]))
            for i in range(y2[batch].item() , y2[batch].item()+75):
                for j in range(x2[batch].item(), x2[batch].item()+75):
                    temp1 = filename[batch] + '_' + 'box2' + '_' + str(i) + '_' + str(j) + '_'
                    submission.append((temp1 + '0', normalized_b[i,j]))
                    submission.append((temp1 + '1', normalized_g[i,j]))
                    submission.append((temp1 + '2', normalized_r[i,j]))
            df = pd.DataFrame(submission, columns=['filename_box_pixel','value'])
    return(df)

# %%
df = submission_data(test_path)
df.to_csv('/kaggle/working/submission.csv',index=False)
# Out:
# Nigga 25 iterations ho gyi: 0
# Nigga 25 iterations ho gyi: 25

# %%
sample_inputs, sample_masks, sample_truths = next(Train_dataiter)
sample_inputs, sample_masks = sample_inputs.cuda(), sample_masks.cuda()

model.eval()
with torch.no_grad():
    sample_preds = model(sample_inputs, sample_masks)

fig, axs = plt.subplots(nrows=4, ncols=4, figsize=(8, 8))

sample_inputs, sample_masks = sample_inputs.cpu(), sample_masks.cpu()
for i in range(4):
    axs[i][0].imshow(np.transpose(sample_truths[i], (1, 2, 0)))
    axs[i][1].imshow(np.transpose(sample_masks[i], (1, 2, 0)))
    axs[i][2].imshow(np.transpose(sample_inputs[i],(1, 2, 0)))
    axs[i][3].imshow(np.transpose(sample_preds[i].cpu(), (1, 2, 0)))
